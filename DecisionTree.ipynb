# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv('Train_v2.csv')
dataset.head(10)
# Out:
#   country  year  ...                  education_level                      job_type
# 0   Kenya  2018  ...              Secondary education                 Self employed
# 1   Kenya  2018  ...              No formal education          Government Dependent
# 2   Kenya  2018  ...  Vocational/Specialised training                 Self employed
# 3   Kenya  2018  ...                Primary education     Formally employed Private
# 4   Kenya  2018  ...                Primary education           Informally employed
# 5   Kenya  2018  ...                Primary education           Informally employed
# 6   Kenya  2018  ...                Primary education                 Self employed
# 7   Kenya  2018  ...               Tertiary education  Formally employed Government
# 8   Kenya  2018  ...              Secondary education           Farming and Fishing
# 9   Kenya  2018  ...              No formal education          Remittance Dependent
#
# [10 rows x 13 columns]

# %%
dataset.isna().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
dataset.pop("uniqueid")
dataset['age_of_respondent'] = pd.to_numeric(dataset['age_of_respondent'], errors='coerce')
dataset['household_size'] = pd.to_numeric(dataset['household_size'], errors='coerce')

# %%
dataset = pd.get_dummies(dataset, prefix='', prefix_sep='', columns=["country", "year", "relationship_with_head", "marital_status", "education_level", "job_type"])
labelencoder = LabelEncoder()
dataset.iloc[:, 0] = labelencoder.fit_transform(dataset.iloc[:, 0].values)
dataset.iloc[:, 1] = labelencoder.fit_transform(dataset.iloc[:, 1].values)
dataset.iloc[:, 2] = labelencoder.fit_transform(dataset.iloc[:, 2].values)
dataset.iloc[:, 5] = labelencoder.fit_transform(dataset.iloc[:, 5].values)
dataset.tail()
# Out:
#        bank_account  location_type  ...  Remittance Dependent  Self employed
# 23519             0              0  ...                     0              0
# 23520             0              0  ...                     0              0
# 23521             0              0  ...                     0              0
# 23522             0              1  ...                     0              1
# 23523             0              0  ...                     0              0
#
# [5 rows x 40 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 40 columns):
# bank_account                       23524 non-null int64
# location_type                      23524 non-null int64
# cellphone_access                   23524 non-null int64
# household_size                     23524 non-null int64
# age_of_respondent                  23524 non-null int64
# gender_of_respondent               23524 non-null int64
# Kenya                              23524 non-null uint8
# Rwanda                             23524 non-null uint8
# Tanzania                           23524 non-null uint8
# Uganda                             23524 non-null uint8
# 2016                               23524 non-null uint8
# 2017                               23524 non-null uint8
# 2018                               23524 non-null uint8
# Child                              23524 non-null uint8
# Head of Household                  23524 non-null uint8
# Other non-relatives                23524 non-null uint8
# Other relative                     23524 non-null uint8
# Parent                             23524 non-null uint8
# Spouse                             23524 non-null uint8
# Divorced/Seperated                 23524 non-null uint8
# Dont know                          23524 non-null uint8
# Married/Living together            23524 non-null uint8
# Single/Never Married               23524 non-null uint8
# Widowed                            23524 non-null uint8
# No formal education                23524 non-null uint8
# Other/Dont know/RTA                23524 non-null uint8
# Primary education                  23524 non-null uint8
# Secondary education                23524 non-null uint8
# Tertiary education                 23524 non-null uint8
# Vocational/Specialised training    23524 non-null uint8
# Dont Know/Refuse to answer         23524 non-null uint8
# Farming and Fishing                23524 non-null uint8
# Formally employed Government       23524 non-null uint8
# Formally employed Private          23524 non-null uint8
# Government Dependent               23524 non-null uint8
# Informally employed                23524 non-null uint8
# No Income                          23524 non-null uint8
# Other Income                       23524 non-null uint8
# Remittance Dependent               23524 non-null uint8
# Self employed                      23524 non-null uint8
# dtypes: int64(6), uint8(34)
# memory usage: 1.8 MB

# %%
dataset.describe()
# Out:
#        bank_account  location_type  ...  Remittance Dependent  Self employed
# count  23524.000000   23524.000000  ...          23524.000000   23524.000000
# mean       0.140792       0.390282  ...              0.107422       0.273635
# std        0.347815       0.487824  ...              0.309656       0.445834
# min        0.000000       0.000000  ...              0.000000       0.000000
# 25%        0.000000       0.000000  ...              0.000000       0.000000
# 50%        0.000000       0.000000  ...              0.000000       0.000000
# 75%        0.000000       1.000000  ...              0.000000       1.000000
# max        1.000000       1.000000  ...              1.000000       1.000000
#
# [8 rows x 40 columns]

# %%
output = dataset.pop("bank_account")
X_train = dataset
Y_train = output

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
dataset_test = pd.read_csv('Test_v2.csv')
dataset_test.head(10)
# Out:
#   country  year  ...                  education_level                      job_type
# 0   Kenya  2018  ...              Secondary education  Formally employed Government
# 1   Kenya  2018  ...  Vocational/Specialised training     Formally employed Private
# 2   Kenya  2018  ...              No formal education          Remittance Dependent
# 3   Kenya  2018  ...                Primary education          Remittance Dependent
# 4   Kenya  2018  ...              Secondary education          Remittance Dependent
# 5   Kenya  2018  ...                Primary education                 Self employed
# 6   Kenya  2018  ...                Primary education           Informally employed
# 7   Kenya  2018  ...  Vocational/Specialised training                 Self employed
# 8   Kenya  2018  ...                Primary education           Informally employed
# 9   Kenya  2018  ...              Secondary education           Farming and Fishing
#
# [10 rows x 12 columns]

# %%
array_id = dataset_test.pop("uniqueid")
array_country = dataset_test['country']

# %%
dataset_test['age_of_respondent'] = pd.to_numeric(dataset['age_of_respondent'], errors='coerce')
dataset_test['household_size'] = pd.to_numeric(dataset['household_size'], errors='coerce')

# %%
dataset_test = pd.get_dummies(dataset_test, prefix='', prefix_sep='', columns=["country", "year", "relationship_with_head", "marital_status", "education_level", "job_type"])
labelencoder = LabelEncoder()
dataset_test.iloc[:, 0] = labelencoder.fit_transform(dataset_test.iloc[:, 0].values)
dataset_test.iloc[:, 1] = labelencoder.fit_transform(dataset_test.iloc[:, 1].values)
dataset_test.iloc[:, 4] = labelencoder.fit_transform(dataset_test.iloc[:, 4].values)
dataset_test.tail()
# Out:
#        location_type  cellphone_access  ...  Remittance Dependent  Self employed
# 10081              0                 0  ...                     0              1
# 10082              1                 1  ...                     0              1
# 10083              1                 1  ...                     0              0
# 10084              0                 1  ...                     0              1
# 10085              1                 1  ...                     0              0
#
# [5 rows x 39 columns]

# %%
X_test = sc_X.fit_transform(dataset_test)

# %%
Y_pred = classifier.predict(X_test)

# %%
file = open("DecisionTree.txt","w") 
file.write("uniqueid,bank_account\n")

for i in range(0, len(X_test)):
    file.write(array_id[i]+" x "+array_country[i]+","+str(Y_pred[i])+"\n")
    
file.close()
